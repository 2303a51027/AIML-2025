# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51027/AIML-2025/blob/main/Lab_Assigment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2024-08-09 131256.png](data:image/png;base64,...)

# %%
import numpy as np


from queue import Queue
graph={0:[1,2,3],1:[0,2],2:[0,1,3,5],
       3:[0,2,4],4:[3,5,7],5:[4,6,7],
       6:[5,7],7:[4,5,6],8:[]}
print("The adjacency list representing the graph is:")
print(graph)

def bfs(graph,source):
  Q=Queue()
  visited_vertices=set()
  Q.put(source)
  visited_vertices.update({source})
  while not Q.empty():
    vertex=Q.get()
    print(vertex,end="-->")
    for u in graph[vertex]:
      if u not in visited_vertices:
        Q.put(u)
        visited_vertices.update({u})
print("BFS traversal of graph with source 0 is:")
bfs(graph,1)
# Out:
# The adjacency list representing the graph is:
# {0: [1, 2, 3], 1: [0, 2], 2: [0, 1, 3, 5], 3: [0, 2, 4], 4: [3, 5, 7], 5: [4, 6, 7], 6: [5, 7], 7: [4, 5, 6], 8: []}
# BFS traversal of graph with source 0 is:
# 1-->0-->2-->3-->5-->4-->6-->7-->

# %% [markdown]
# ![Screenshot 2024-08-09 1313211.png](data:image/png;base64,...)

# %%
graph1 = {
    'A':['C','D','G'],
    'B':['A'],
    'C':['A','D','F'],
    'D':['A','C','E','G','H'],
    'E':['D','F','H'],
    'F':['C','E'],
    'G':['A','D','H'],
    'H':['D','E','G'],
    }
print("The adjacency List representing the graph is:")
print(graph1)

def dfs(graph, node, visited):
    if node not in visited:
        visited.append(node)
        for k in graph[node]:
            dfs(graph, k, visited)
    return visited

graph1 = {
    'A':['C','D','G'],
    'B':['A'],
    'C':['A','D','F'],
    'D':['A','C','E','G','H'],
    'E':['D','F','H'],
    'F':['C','E'],
    'G':['A','D','H'],
    'H':['D','E','G'],
}
visited = dfs(graph1, 'B', [])
print(visited)
# Out:
# The adjacency List representing the graph is:
# {'A': ['C', 'D', 'G'], 'B': ['A'], 'C': ['A', 'D', 'F'], 'D': ['A', 'C', 'E', 'G', 'H'], 'E': ['D', 'F', 'H'], 'F': ['C', 'E'], 'G': ['A', 'D', 'H'], 'H': ['D', 'E', 'G']}
# ['B', 'A', 'C', 'D', 'E', 'F', 'H', 'G']
